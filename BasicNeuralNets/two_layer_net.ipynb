# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from asgn1.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `asgn1/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `asgn1/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027209324e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from asgn1.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# W1 max relative error: 3.669857e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447687e-11
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from asgn1.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from asgn1.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
'''
from sklearn.decomposition import PCA
pca = PCA(n_components=1000)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_val_pca = pca.transform(X_val)
X_test_pca = pca.transform(X_test)
'''

# %%
best_net = None # store the best model into this 
np.random.seed(0)

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################

# Use the validation set to tune the learning rate and regularization strength
input_size = X_train.shape[1]
num_classes = 10

hidden_sizes = [ 170, 200, 230, 260]
learning_rates = [5e-5,7e-5,1e-3,5e-4,7e-4,3e-5]
regularization_strengths = [1e-2,5e-3]

results = {}
best_val = -1
#choose the best hyperparameter
for hidden_size in hidden_sizes:
    net = TwoLayerNet(input_size, hidden_size, num_classes)
    for learning_rate in learning_rates:
        for regularization_strength in regularization_strengths:
            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                        num_iters=1000, batch_size=200,
                        learning_rate=learning_rate, learning_rate_decay=0.95,
                        reg=regularization_strength, verbose=True)

            # Predict on the training set
            train_acc = (net.predict(X_train) == y_train).mean()

            # Predict on the validation set
            val_acc = (net.predict(X_val) == y_val).mean()

            #store in dict
            results[(learning_rate, regularization_strength, hidden_size)] = (train_acc, val_acc)
            #save best validation
            if val_acc > best_val: 
                best_val = val_acc 
                best_net = net
        

# Print out results.
for lr, reg, hs in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg, hs)]
    print 'lr %e reg %e hs %d train accuracy: %f val accuracy: %f ' % (
                lr, reg, hs, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during validation: %f' % best_val
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 1000: loss 2.302611
# iteration 100 / 1000: loss 2.302189
# iteration 200 / 1000: loss 2.300998
# iteration 300 / 1000: loss 2.296658
# iteration 400 / 1000: loss 2.285137
# iteration 500 / 1000: loss 2.246099
# iteration 600 / 1000: loss 2.210249
# iteration 700 / 1000: loss 2.215338
# iteration 800 / 1000: loss 2.158452
# iteration 900 / 1000: loss 2.122088
# iteration 0 / 1000: loss 2.081113
# iteration 100 / 1000: loss 2.043491
# iteration 200 / 1000: loss 2.038988
# iteration 300 / 1000: loss 2.093080
# iteration 400 / 1000: loss 2.000419
# iteration 500 / 1000: loss 1.953859
# iteration 600 / 1000: loss 1.995407
# iteration 700 / 1000: loss 2.046519
# iteration 800 / 1000: loss 2.006099
# iteration 900 / 1000: loss 1.856365
# iteration 0 / 1000: loss 1.930770
# iteration 100 / 1000: loss 1.809503
# iteration 200 / 1000: loss 1.843756
# iteration 300 / 1000: loss 1.803104
# iteration 400 / 1000: loss 1.825831
# iteration 500 / 1000: loss 1.767911
# iteration 600 / 1000: loss 1.854507
# iteration 700 / 1000: loss 1.841726
# iteration 800 / 1000: loss 1.779240
# iteration 900 / 1000: loss 1.754287
# iteration 0 / 1000: loss 1.722492
# iteration 100 / 1000: loss 1.764035
# iteration 200 / 1000: loss 1.759742
# iteration 300 / 1000: loss 1.839767
# iteration 400 / 1000: loss 1.680906
# iteration 500 / 1000: loss 1.675122
# iteration 600 / 1000: loss 1.662006
# iteration 700 / 1000: loss 1.710389
# iteration 800 / 1000: loss 1.795431
# iteration 900 / 1000: loss 1.746795
# iteration 0 / 1000: loss 1.719155
# iteration 100 / 1000: loss 1.617030
# iteration 200 / 1000: loss 1.569404
# iteration 300 / 1000: loss 1.526236
# iteration 400 / 1000: loss 1.374632
# iteration 500 / 1000: loss 1.457506
# iteration 600 / 1000: loss 1.470570
# iteration 700 / 1000: loss 1.464458
# iteration 800 / 1000: loss 1.396702
# iteration 900 / 1000: loss 1.413211
# iteration 0 / 1000: loss 1.240928
# iteration 100 / 1000: loss 1.301207
# iteration 200 / 1000: loss 1.414457
# iteration 300 / 1000: loss 1.338484
# iteration 400 / 1000: loss 1.307813
# iteration 500 / 1000: loss 1.293306
# iteration 600 / 1000: loss 1.375745
# iteration 700 / 1000: loss 1.377007
# iteration 800 / 1000: loss 1.245157
# iteration 900 / 1000: loss 1.168537
# iteration 0 / 1000: loss 1.091152
# iteration 100 / 1000: loss 1.179438
# iteration 200 / 1000: loss 1.178724
# iteration 300 / 1000: loss 1.089656
# iteration 400 / 1000: loss 1.112304
# iteration 500 / 1000: loss 1.138432
# iteration 600 / 1000: loss 1.069230
# iteration 700 / 1000: loss 1.119054
# iteration 800 / 1000: loss 1.042645
# iteration 900 / 1000: loss 1.071352
# iteration 0 / 1000: loss 1.069383
# iteration 100 / 1000: loss 1.041832
# iteration 200 / 1000: loss 1.006408
# iteration 300 / 1000: loss 1.130986
# iteration 400 / 1000: loss 0.933058
# iteration 500 / 1000: loss 0.971078
# iteration 600 / 1000: loss 1.065241
# iteration 700 / 1000: loss 1.055373
# iteration 800 / 1000: loss 1.034923
# iteration 900 / 1000: loss 0.976975
# iteration 0 / 1000: loss 0.950352
# iteration 100 / 1000: loss 0.939662
# iteration 200 / 1000: loss 1.052884
# iteration 300 / 1000: loss 0.988450
# iteration 400 / 1000: loss 1.039641
# iteration 500 / 1000: loss 1.142866
# iteration 600 / 1000: loss 1.040920
# iteration 700 / 1000: loss 1.046897
# iteration 800 / 1000: loss 0.941237
# iteration 900 / 1000: loss 0.897480
# iteration 0 / 1000: loss 1.007083
# iteration 100 / 1000: loss 0.932612
# iteration 200 / 1000: loss 1.071039
# iteration 300 / 1000: loss 1.117437
# iteration 400 / 1000: loss 0.952831
# iteration 500 / 1000: loss 0.967243
# iteration 600 / 1000: loss 0.892798
# iteration 700 / 1000: loss 1.011188
# iteration 800 / 1000: loss 0.805684
# iteration 900 / 1000: loss 0.929641
# iteration 0 / 1000: loss 1.124818
# iteration 100 / 1000: loss 0.704610
# iteration 200 / 1000: loss 0.799508
# iteration 300 / 1000: loss 0.691072
# iteration 400 / 1000: loss 0.825401
# iteration 500 / 1000: loss 0.684074
# iteration 600 / 1000: loss 0.819795
# iteration 700 / 1000: loss 0.811424
# iteration 800 / 1000: loss 0.811877
# iteration 900 / 1000: loss 0.762868
# iteration 0 / 1000: loss 0.746427
# iteration 100 / 1000: loss 0.777337
# iteration 200 / 1000: loss 0.840578
# iteration 300 / 1000: loss 0.819474
# iteration 400 / 1000: loss 0.737241
# iteration 500 / 1000: loss 0.741692
# iteration 600 / 1000: loss 0.898758
# iteration 700 / 1000: loss 0.876173
# iteration 800 / 1000: loss 0.813737
# iteration 900 / 1000: loss 0.862110
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 2.302178
# iteration 200 / 1000: loss 2.300921
# iteration 300 / 1000: loss 2.297144
# iteration 400 / 1000: loss 2.285979
# iteration 500 / 1000: loss 2.268930
# iteration 600 / 1000: loss 2.216578
# iteration 700 / 1000: loss 2.233929
# iteration 800 / 1000: loss 2.163286
# iteration 900 / 1000: loss 2.092559
# iteration 0 / 1000: loss 2.060783
# iteration 100 / 1000: loss 2.019796
# iteration 200 / 1000: loss 2.043666
# iteration 300 / 1000: loss 2.061080
# iteration 400 / 1000: loss 2.028950
# iteration 500 / 1000: loss 1.938396
# iteration 600 / 1000: loss 1.940367
# iteration 700 / 1000: loss 1.953044
# iteration 800 / 1000: loss 1.917966
# iteration 900 / 1000: loss 1.850673
# iteration 0 / 1000: loss 1.811037
# iteration 100 / 1000: loss 1.890897
# iteration 200 / 1000: loss 1.868010
# iteration 300 / 1000: loss 1.814512
# iteration 400 / 1000: loss 1.851173
# iteration 500 / 1000: loss 1.785901
# iteration 600 / 1000: loss 1.787780
# iteration 700 / 1000: loss 1.807509
# iteration 800 / 1000: loss 1.787070
# iteration 900 / 1000: loss 1.785871
# iteration 0 / 1000: loss 1.713696
# iteration 100 / 1000: loss 1.712043
# iteration 200 / 1000: loss 1.707846
# iteration 300 / 1000: loss 1.751980
# iteration 400 / 1000: loss 1.697832
# iteration 500 / 1000: loss 1.784396
# iteration 600 / 1000: loss 1.714874
# iteration 700 / 1000: loss 1.808055
# iteration 800 / 1000: loss 1.669472
# iteration 900 / 1000: loss 1.704815
# iteration 0 / 1000: loss 1.694877
# iteration 100 / 1000: loss 1.645116
# iteration 200 / 1000: loss 1.714682
# iteration 300 / 1000: loss 1.417486
# iteration 400 / 1000: loss 1.631730
# iteration 500 / 1000: loss 1.563345
# iteration 600 / 1000: loss 1.266755
# iteration 700 / 1000: loss 1.428570
# iteration 800 / 1000: loss 1.354380
# iteration 900 / 1000: loss 1.342583
# iteration 0 / 1000: loss 1.305515
# iteration 100 / 1000: loss 1.261455
# iteration 200 / 1000: loss 1.188417
# iteration 300 / 1000: loss 1.479542
# iteration 400 / 1000: loss 1.334656
# iteration 500 / 1000: loss 1.380802
# iteration 600 / 1000: loss 1.340638
# iteration 700 / 1000: loss 1.445735
# iteration 800 / 1000: loss 1.298352
# iteration 900 / 1000: loss 1.147485
# iteration 0 / 1000: loss 1.032985
# iteration 100 / 1000: loss 1.087093
# iteration 200 / 1000: loss 1.080865
# iteration 300 / 1000: loss 1.016086
# iteration 400 / 1000: loss 1.103775
# iteration 500 / 1000: loss 1.156276
# iteration 600 / 1000: loss 1.051532
# iteration 700 / 1000: loss 1.135659
# iteration 800 / 1000: loss 0.992650
# iteration 900 / 1000: loss 0.919855
# iteration 0 / 1000: loss 1.088765
# iteration 100 / 1000: loss 1.113804
# iteration 200 / 1000: loss 0.978577
# iteration 300 / 1000: loss 1.030860
# iteration 400 / 1000: loss 1.052611
# iteration 500 / 1000: loss 1.031919
# iteration 600 / 1000: loss 0.977765
# iteration 700 / 1000: loss 0.962543
# iteration 800 / 1000: loss 1.015237
# iteration 900 / 1000: loss 0.854556
# iteration 0 / 1000: loss 1.104951
# iteration 100 / 1000: loss 1.198237
# iteration 200 / 1000: loss 0.943548
# iteration 300 / 1000: loss 0.967230
# iteration 400 / 1000: loss 0.856179
# iteration 500 / 1000: loss 0.956547
# iteration 600 / 1000: loss 0.986905
# iteration 700 / 1000: loss 0.928945
# iteration 800 / 1000: loss 0.956470
# iteration 900 / 1000: loss 0.889262
# iteration 0 / 1000: loss 0.929615
# iteration 100 / 1000: loss 0.983203
# iteration 200 / 1000: loss 1.085033
# iteration 300 / 1000: loss 1.079196
# iteration 400 / 1000: loss 0.791448
# iteration 500 / 1000: loss 1.063028
# iteration 600 / 1000: loss 0.845362
# iteration 700 / 1000: loss 0.938590
# iteration 800 / 1000: loss 0.999000
# iteration 900 / 1000: loss 0.783969
# iteration 0 / 1000: loss 0.928091
# iteration 100 / 1000: loss 0.812641
# iteration 200 / 1000: loss 0.670433
# iteration 300 / 1000: loss 0.755990
# iteration 400 / 1000: loss 0.711916
# iteration 500 / 1000: loss 0.860463
# iteration 600 / 1000: loss 0.820727
# iteration 700 / 1000: loss 0.688343
# iteration 800 / 1000: loss 0.765286
# iteration 900 / 1000: loss 0.675485
# iteration 0 / 1000: loss 0.741023
# iteration 100 / 1000: loss 0.738986
# iteration 200 / 1000: loss 0.712787
# iteration 300 / 1000: loss 0.717840
# iteration 400 / 1000: loss 0.718503
# iteration 500 / 1000: loss 0.705807
# iteration 600 / 1000: loss 0.770247
# iteration 700 / 1000: loss 0.732215
# iteration 800 / 1000: loss 0.618257
# iteration 900 / 1000: loss 0.741418
# iteration 0 / 1000: loss 2.302644
# iteration 100 / 1000: loss 2.302016
# iteration 200 / 1000: loss 2.300775
# iteration 300 / 1000: loss 2.297303
# iteration 400 / 1000: loss 2.282985
# iteration 500 / 1000: loss 2.260677
# iteration 600 / 1000: loss 2.188235
# iteration 700 / 1000: loss 2.194689
# iteration 800 / 1000: loss 2.179535
# iteration 900 / 1000: loss 2.111044
# iteration 0 / 1000: loss 2.075235
# iteration 100 / 1000: loss 2.101508
# iteration 200 / 1000: loss 2.018041
# iteration 300 / 1000: loss 1.999010
# iteration 400 / 1000: loss 1.989028
# iteration 500 / 1000: loss 1.919430
# iteration 600 / 1000: loss 1.972368
# iteration 700 / 1000: loss 1.890176
# iteration 800 / 1000: loss 1.893221
# iteration 900 / 1000: loss 1.945936
# iteration 0 / 1000: loss 1.892245
# iteration 100 / 1000: loss 1.911979
# iteration 200 / 1000: loss 1.752420
# iteration 300 / 1000: loss 1.864708
# iteration 400 / 1000: loss 1.890719
# iteration 500 / 1000: loss 1.883228
# iteration 600 / 1000: loss 1.745594
# iteration 700 / 1000: loss 1.898265
# iteration 800 / 1000: loss 1.916257
# iteration 900 / 1000: loss 1.749974
# iteration 0 / 1000: loss 1.734164
# iteration 100 / 1000: loss 1.783935
# iteration 200 / 1000: loss 1.689038
# iteration 300 / 1000: loss 1.654770
# iteration 400 / 1000: loss 1.788737
# iteration 500 / 1000: loss 1.753533
# iteration 600 / 1000: loss 1.739644
# iteration 700 / 1000: loss 1.624379
# iteration 800 / 1000: loss 1.763370
# iteration 900 / 1000: loss 1.633761
# iteration 0 / 1000: loss 1.849752
# iteration 100 / 1000: loss 1.638574
# iteration 200 / 1000: loss 1.613432
# iteration 300 / 1000: loss 1.465861
# iteration 400 / 1000: loss 1.486822
# iteration 500 / 1000: loss 1.396540
# iteration 600 / 1000: loss 1.527726
# iteration 700 / 1000: loss 1.383693
# iteration 800 / 1000: loss 1.357822
# iteration 900 / 1000: loss 1.517565
# iteration 0 / 1000: loss 1.464931
# iteration 100 / 1000: loss 1.273791
# iteration 200 / 1000: loss 1.190067
# iteration 300 / 1000: loss 1.230027
# iteration 400 / 1000: loss 1.273652
# iteration 500 / 1000: loss 1.266897
# iteration 600 / 1000: loss 1.232139
# iteration 700 / 1000: loss 1.119686
# iteration 800 / 1000: loss 1.226935
# iteration 900 / 1000: loss 1.219996
# iteration 0 / 1000: loss 1.089455
# iteration 100 / 1000: loss 1.130308
# iteration 200 / 1000: loss 0.983955
# iteration 300 / 1000: loss 0.969231
# iteration 400 / 1000: loss 1.024503
# iteration 500 / 1000: loss 1.187889
# iteration 600 / 1000: loss 1.010386
# iteration 700 / 1000: loss 1.060579
# iteration 800 / 1000: loss 1.042437
# iteration 900 / 1000: loss 1.008411
# iteration 0 / 1000: loss 0.963522
# iteration 100 / 1000: loss 1.245266
# iteration 200 / 1000: loss 1.102618
# iteration 300 / 1000: loss 1.120167
# iteration 400 / 1000: loss 1.096388
# iteration 500 / 1000: loss 0.907627
# iteration 600 / 1000: loss 0.862859
# iteration 700 / 1000: loss 0.992124
# iteration 800 / 1000: loss 0.964933
# iteration 900 / 1000: loss 1.004173
# iteration 0 / 1000: loss 0.950961
# iteration 100 / 1000: loss 1.095380
# iteration 200 / 1000: loss 1.068460
# iteration 300 / 1000: loss 0.866498
# iteration 400 / 1000: loss 0.928216
# iteration 500 / 1000: loss 0.977246
# iteration 600 / 1000: loss 0.941075
# iteration 700 / 1000: loss 0.874071
# iteration 800 / 1000: loss 0.984162
# iteration 900 / 1000: loss 1.038203
# iteration 0 / 1000: loss 0.976127
# iteration 100 / 1000: loss 0.915763
# iteration 200 / 1000: loss 1.119148
# iteration 300 / 1000: loss 0.908700
# iteration 400 / 1000: loss 0.733182
# iteration 500 / 1000: loss 0.744139
# iteration 600 / 1000: loss 0.966967
# iteration 700 / 1000: loss 1.182880
# iteration 800 / 1000: loss 0.802037
# iteration 900 / 1000: loss 0.967077
# iteration 0 / 1000: loss 0.786685
# iteration 100 / 1000: loss 0.768717
# iteration 200 / 1000: loss 0.703831
# iteration 300 / 1000: loss 0.779264
# iteration 400 / 1000: loss 0.860919
# iteration 500 / 1000: loss 0.671707
# iteration 600 / 1000: loss 0.670800
# iteration 700 / 1000: loss 0.797666
# iteration 800 / 1000: loss 0.720682
# iteration 900 / 1000: loss 0.674739
# iteration 0 / 1000: loss 0.795944
# iteration 100 / 1000: loss 0.702483
# iteration 200 / 1000: loss 0.746055
# iteration 300 / 1000: loss 0.742546
# iteration 400 / 1000: loss 0.777027
# iteration 500 / 1000: loss 0.772052
# iteration 600 / 1000: loss 0.854433
# iteration 700 / 1000: loss 0.654721
# iteration 800 / 1000: loss 0.635528
# iteration 900 / 1000: loss 0.667943
# iteration 0 / 1000: loss 2.302648
# iteration 100 / 1000: loss 2.301885
# iteration 200 / 1000: loss 2.300057
# iteration 300 / 1000: loss 2.294804
# iteration 400 / 1000: loss 2.279338
# iteration 500 / 1000: loss 2.253338
# iteration 600 / 1000: loss 2.204714
# iteration 700 / 1000: loss 2.156159
# iteration 800 / 1000: loss 2.096769
# iteration 900 / 1000: loss 2.098535
# iteration 0 / 1000: loss 2.116851
# iteration 100 / 1000: loss 2.093299
# iteration 200 / 1000: loss 2.073593
# iteration 300 / 1000: loss 2.033919
# iteration 400 / 1000: loss 2.013701
# iteration 500 / 1000: loss 2.023448
# iteration 600 / 1000: loss 1.994123
# iteration 700 / 1000: loss 1.920520
# iteration 800 / 1000: loss 2.004054
# iteration 900 / 1000: loss 1.873851
# iteration 0 / 1000: loss 1.970789
# iteration 100 / 1000: loss 2.019460
# iteration 200 / 1000: loss 1.897483
# iteration 300 / 1000: loss 1.800316
# iteration 400 / 1000: loss 1.786236
# iteration 500 / 1000: loss 1.882456
# iteration 600 / 1000: loss 1.817409
# iteration 700 / 1000: loss 1.767299
# iteration 800 / 1000: loss 1.867588
# iteration 900 / 1000: loss 1.903021
# iteration 0 / 1000: loss 1.806017
# iteration 100 / 1000: loss 1.699422
# iteration 200 / 1000: loss 1.734898
# iteration 300 / 1000: loss 1.721260
# iteration 400 / 1000: loss 1.770100
# iteration 500 / 1000: loss 1.669700
# iteration 600 / 1000: loss 1.645013
# iteration 700 / 1000: loss 1.718919
# iteration 800 / 1000: loss 1.769458
# iteration 900 / 1000: loss 1.686122
# iteration 0 / 1000: loss 1.749659
# iteration 100 / 1000: loss 1.627620
# iteration 200 / 1000: loss 1.510274
# iteration 300 / 1000: loss 1.564713
# iteration 400 / 1000: loss 1.668857
# iteration 500 / 1000: loss 1.406557
# iteration 600 / 1000: loss 1.465597
# iteration 700 / 1000: loss 1.360145
# iteration 800 / 1000: loss 1.346842
# iteration 900 / 1000: loss 1.407552
# iteration 0 / 1000: loss 1.293987
# iteration 100 / 1000: loss 1.407997
# iteration 200 / 1000: loss 1.368779
# iteration 300 / 1000: loss 1.305608
# iteration 400 / 1000: loss 1.209743
# iteration 500 / 1000: loss 1.250842
# iteration 600 / 1000: loss 1.316149
# iteration 700 / 1000: loss 1.330672
# iteration 800 / 1000: loss 1.231965
# iteration 900 / 1000: loss 1.217041
# iteration 0 / 1000: loss 1.162547
# iteration 100 / 1000: loss 1.118306
# iteration 200 / 1000: loss 1.203338
# iteration 300 / 1000: loss 1.045339
# iteration 400 / 1000: loss 1.294781
# iteration 500 / 1000: loss 1.164455
# iteration 600 / 1000: loss 1.008366
# iteration 700 / 1000: loss 1.110667
# iteration 800 / 1000: loss 0.975236
# iteration 900 / 1000: loss 1.003411
# iteration 0 / 1000: loss 1.001568
# iteration 100 / 1000: loss 1.097499
# iteration 200 / 1000: loss 0.969723
# iteration 300 / 1000: loss 0.932216
# iteration 400 / 1000: loss 0.959693
# iteration 500 / 1000: loss 1.009168
# iteration 600 / 1000: loss 0.900211
# iteration 700 / 1000: loss 0.902184
# iteration 800 / 1000: loss 0.883470
# iteration 900 / 1000: loss 1.001598
# iteration 0 / 1000: loss 0.954500
# iteration 100 / 1000: loss 0.987860
# iteration 200 / 1000: loss 1.093801
# iteration 300 / 1000: loss 1.046178
# iteration 400 / 1000: loss 1.012171
# iteration 500 / 1000: loss 0.956636
# iteration 600 / 1000: loss 0.947118
# iteration 700 / 1000: loss 0.914426
# iteration 800 / 1000: loss 0.929600
# iteration 900 / 1000: loss 0.909494
# iteration 0 / 1000: loss 0.848325
# iteration 100 / 1000: loss 1.008209
# iteration 200 / 1000: loss 1.033020
# iteration 300 / 1000: loss 0.960498
# iteration 400 / 1000: loss 1.029385
# iteration 500 / 1000: loss 0.881756
# iteration 600 / 1000: loss 0.876935
# iteration 700 / 1000: loss 0.952443
# iteration 800 / 1000: loss 0.803971
# iteration 900 / 1000: loss 0.825373
# iteration 0 / 1000: loss 0.763701
# iteration 100 / 1000: loss 0.823925
# iteration 200 / 1000: loss 0.798051
# iteration 300 / 1000: loss 0.776873
# iteration 400 / 1000: loss 0.772501
# iteration 500 / 1000: loss 0.689785
# iteration 600 / 1000: loss 0.736110
# iteration 700 / 1000: loss 0.748766
# iteration 800 / 1000: loss 0.743054
# iteration 900 / 1000: loss 0.748465
# iteration 0 / 1000: loss 0.750974
# iteration 100 / 1000: loss 0.713853
# iteration 200 / 1000: loss 0.694020
# iteration 300 / 1000: loss 0.681772
# iteration 400 / 1000: loss 0.666129
# iteration 500 / 1000: loss 0.739874
# iteration 600 / 1000: loss 0.673786
# iteration 700 / 1000: loss 0.675117
# iteration 800 / 1000: loss 0.646580
# iteration 900 / 1000: loss 0.659756
# lr 3.000000e-05 reg 5.000000e-03 hs 170 train accuracy: 0.749367 val accuracy: 0.541000
# lr 3.000000e-05 reg 5.000000e-03 hs 200 train accuracy: 0.763327 val accuracy: 0.544000
# lr 3.000000e-05 reg 5.000000e-03 hs 230 train accuracy: 0.771796 val accuracy: 0.555000
# lr 3.000000e-05 reg 5.000000e-03 hs 260 train accuracy: 0.781735 val accuracy: 0.556000
# lr 3.000000e-05 reg 1.000000e-02 hs 170 train accuracy: 0.745653 val accuracy: 0.548000
# lr 3.000000e-05 reg 1.000000e-02 hs 200 train accuracy: 0.757306 val accuracy: 0.543000
# lr 3.000000e-05 reg 1.000000e-02 hs 230 train accuracy: 0.767041 val accuracy: 0.551000
# lr 3.000000e-05 reg 1.000000e-02 hs 260 train accuracy: 0.774980 val accuracy: 0.561000
# lr 5.000000e-05 reg 5.000000e-03 hs 170 train accuracy: 0.307857 val accuracy: 0.312000
# lr 5.000000e-05 reg 5.000000e-03 hs 200 train accuracy: 0.310347 val accuracy: 0.310000
# lr 5.000000e-05 reg 5.000000e-03 hs 230 train accuracy: 0.310020 val accuracy: 0.309000
# lr 5.000000e-05 reg 5.000000e-03 hs 260 train accuracy: 0.314531 val accuracy: 0.315000
# lr 5.000000e-05 reg 1.000000e-02 hs 170 train accuracy: 0.229469 val accuracy: 0.244000
# lr 5.000000e-05 reg 1.000000e-02 hs 200 train accuracy: 0.230020 val accuracy: 0.246000
# lr 5.000000e-05 reg 1.000000e-02 hs 230 train accuracy: 0.225327 val accuracy: 0.238000
# lr 5.000000e-05 reg 1.000000e-02 hs 260 train accuracy: 0.231878 val accuracy: 0.246000
# lr 7.000000e-05 reg 5.000000e-03 hs 170 train accuracy: 0.399571 val accuracy: 0.388000
# lr 7.000000e-05 reg 5.000000e-03 hs 200 train accuracy: 0.399939 val accuracy: 0.398000
# lr 7.000000e-05 reg 5.000000e-03 hs 230 train accuracy: 0.398673 val accuracy: 0.397000
# lr 7.000000e-05 reg 5.000000e-03 hs 260 train accuracy: 0.402510 val accuracy: 0.406000
# lr 7.000000e-05 reg 1.000000e-02 hs 170 train accuracy: 0.365612 val accuracy: 0.371000
# lr 7.000000e-05 reg 1.000000e-02 hs 200 train accuracy: 0.365388 val accuracy: 0.371000
# lr 7.000000e-05 reg 1.000000e-02 hs 230 train accuracy: 0.365816 val accuracy: 0.369000
# lr 7.000000e-05 reg 1.000000e-02 hs 260 train accuracy: 0.368878 val accuracy: 0.369000
# lr 5.000000e-04 reg 5.000000e-03 hs 170 train accuracy: 0.664653 val accuracy: 0.546000
# lr 5.000000e-04 reg 5.000000e-03 hs 200 train accuracy: 0.669816 val accuracy: 0.533000
# lr 5.000000e-04 reg 5.000000e-03 hs 230 train accuracy: 0.664000 val accuracy: 0.541000
# lr 5.000000e-04 reg 5.000000e-03 hs 260 train accuracy: 0.677837 val accuracy: 0.561000
# lr 5.000000e-04 reg 1.000000e-02 hs 170 train accuracy: 0.638857 val accuracy: 0.537000
# lr 5.000000e-04 reg 1.000000e-02 hs 200 train accuracy: 0.644714 val accuracy: 0.544000
# lr 5.000000e-04 reg 1.000000e-02 hs 230 train accuracy: 0.649980 val accuracy: 0.546000
# lr 5.000000e-04 reg 1.000000e-02 hs 260 train accuracy: 0.654673 val accuracy: 0.554000
# lr 7.000000e-04 reg 5.000000e-03 hs 170 train accuracy: 0.667286 val accuracy: 0.487000
# lr 7.000000e-04 reg 5.000000e-03 hs 200 train accuracy: 0.712796 val accuracy: 0.538000
# lr 7.000000e-04 reg 5.000000e-03 hs 230 train accuracy: 0.724816 val accuracy: 0.532000
# lr 7.000000e-04 reg 5.000000e-03 hs 260 train accuracy: 0.727204 val accuracy: 0.557000
# lr 7.000000e-04 reg 1.000000e-02 hs 170 train accuracy: 0.666347 val accuracy: 0.525000
# lr 7.000000e-04 reg 1.000000e-02 hs 200 train accuracy: 0.688469 val accuracy: 0.536000
# lr 7.000000e-04 reg 1.000000e-02 hs 230 train accuracy: 0.676327 val accuracy: 0.508000
# lr 7.000000e-04 reg 1.000000e-02 hs 260 train accuracy: 0.700571 val accuracy: 0.538000
# lr 1.000000e-03 reg 5.000000e-03 hs 170 train accuracy: 0.595571 val accuracy: 0.517000
# lr 1.000000e-03 reg 5.000000e-03 hs 200 train accuracy: 0.597184 val accuracy: 0.515000
# lr 1.000000e-03 reg 5.000000e-03 hs 230 train accuracy: 0.600020 val accuracy: 0.523000
# lr 1.000000e-03 reg 5.000000e-03 hs 260 train accuracy: 0.596306 val accuracy: 0.520000
# lr 1.000000e-03 reg 1.000000e-02 hs 170 train accuracy: 0.542265 val accuracy: 0.501000
# lr 1.000000e-03 reg 1.000000e-02 hs 200 train accuracy: 0.533755 val accuracy: 0.514000
# lr 1.000000e-03 reg 1.000000e-02 hs 230 train accuracy: 0.534224 val accuracy: 0.491000
# lr 1.000000e-03 reg 1.000000e-02 hs 260 train accuracy: 0.535592 val accuracy: 0.522000
# best validation accuracy achieved during validation: 0.561000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.545
